# %% [markdown]
# # Titanic Disaster

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import csv as csv

# %%
data = pd.read_csv("data/train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# Now that we have the pandas dataframe, lets experiment with getting the number of passengers who survived.

# %%
total_passengers = len(data["PassengerId"])
print("Total Passengers: %s" % total_passengers)

total_survived = np.sum(data["Survived"])
print("Total Survived: %s" % total_survived)
# Out:
# Total Passengers: 891
# Total Survived: 342

# %% [markdown]
# ## Find the male and female stats

# %% [markdown]
# ### Female Stats

# %%
women_only_stats = data.loc[data["Sex"] == "female"]
women_only_stats
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %% [markdown]
# ### Male Stats

# %%
men_only_stats = data.loc[data["Sex"] == "male"]
men_only_stats
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %% [markdown]
# ## Proportions

# %% [markdown]
# Now that we have the proportions, we can use that to figure out how many females and males died in the incident.

# %%
total_women = len(women_only_stats)
women_survived = len(women_only_stats.loc[data["Survived"] == 1])
proportion_women_survived = women_survived / total_women
print("Ratio Women Survived: %s" % proportion_women_survived)
# Out:
# Ratio Women Survived: 0.7420382165605095

# %%
total_men = len(men_only_stats)
men_survived = len(men_only_stats.loc[data["Survived"] == 1])
proportion_men_survived = men_survived / total_men
print("Ratio Men Survived: %s" % proportion_men_survived)
# Out:
# Ratio Men Survived: 0.18890814558058924

# %% [markdown]
# ## Gender based Prediction

# %% [markdown]
# Read the test file and create a gender file.

# %%
testdata = pd.read_csv("data/test.csv")
testdata
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
rows = []
for index, row in testdata.iterrows():
    if row['Sex'] == "female":
        rows.append([row["PassengerId"], 1])
    else:
        rows.append([row["PassengerId"], 0])
        
df = pd.DataFrame(rows, columns=["PassengerId", "Survived"])
df.to_csv("output/genderbasedmodel.csv")
